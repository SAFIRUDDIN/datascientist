# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil_image = Image.open("earth.jpg")

# %%
img = np.array(pil_image)

# %%
plt.imshow(img)

# %%
top_left = img[:1000,:1000]

# %%
top_right = img[:1000,2000:]

# %%
hs = np.vstack([top_left,top_right])

# %%
plt.imshow(hs)
