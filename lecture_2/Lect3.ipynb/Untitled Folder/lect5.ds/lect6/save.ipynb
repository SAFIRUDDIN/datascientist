# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
pil_image = Image.open("earth.jpg")
img = np.array(pil_image)
plt.imshow(img)

# %%
target=Image.fromarray(img)

# %%
s=open("target.jpg","wb")
target.save(s)

# %%
img[:,:,1] = 0
plt.imshow(img)

# %%
new_img=img[::3,::]
plt.imshow(new_img)

# %%
new_img[:,:,2] = 255
plt.imshow(new_img)

# %%
plt.imshow(new_img[::10,::10])

# %%
img[:,:,1] = 0
plt.imshow(img)
