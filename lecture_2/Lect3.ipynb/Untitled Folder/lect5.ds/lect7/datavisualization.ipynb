# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[1,5,7,10])

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x=np.linspace(-np.pi,np.pi)

# %%
y=np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,x**2)
plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))
plt.subplot(2,2,2)
plt.plot(x,np.cos(x))
plt.subplot(2,2,3)
plt.plot(x,x**2)
plt.subplot(2,2,4)
plt.plot(x,np.tan(x))
plt.show()

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))
plt.subplot(2,2,3)
plt.plot(x,np.cos(x))
plt.subplot(2,2,4)
plt.plot(x,x**2)

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,x**2)
plt.subplot(2,2,2)
plt.plot(x,np.sin(x))
plt.subplot(2,2,4)
plt.plot(x,x**2)
plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))
plt.subplot(2,2,4)
plt.plot(x,np.cos(x))
plt.subplot(2,2,3)
plt.plot(x,x**2)

# %%
plt.plot(x,x**2,label="Square",color="green")
plt.plot(x,x**3,label="Cube",color="red")
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.xlabel("ye hai X axis")
plt.ylabel("ye hai y axis")
plt.title("Pure 20 marks")
plt.legend()
plt.show()

# %%
plt.scatter(x,x**2,label="Square",color="green",marker="*")
plt.scatter(x,x**3,label="Cube",color="red",marker="^")
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.xlabel("ye hai X axis")
plt.ylabel("ye hai y axis")
plt.title("Pure 20 marks")
plt.legend()
plt.show()

# %%
plt.bar(x,x**2,label="Square",color="green")
plt.bar(x,x**3,label="Cube",color="red")
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.xlabel("ye hai X axis")
plt.ylabel("ye hai y axis")
plt.title("Pure 20 marks")
plt.legend()
plt.show()

# %%
plt.pie(x,x**2)
plt.pie(x,x**3)
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.xlabel("ye hai X axis")
plt.ylabel("ye hai y axis")
plt.title("Pure 20 marks")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
a=np.random.randn(1000)
plt.hist(a,bins=50)
# Out:
# (array([ 1.,  0.,  1.,  1.,  0.,  1.,  1.,  1.,  3.,  3.,  4.,  5., 12.,
#         13., 10., 17., 20., 19., 37., 27., 35., 35., 45., 48., 56., 63.,
#         65., 57., 43., 55., 48., 50., 35., 34., 42., 27., 17., 19., 10.,
#         16.,  2.,  8.,  2.,  6.,  2.,  1.,  1.,  0.,  1.,  1.]),
#  array([-3.64066787, -3.50103014, -3.36139241, -3.22175469, -3.08211696,
#         -2.94247924, -2.80284151, -2.66320379, -2.52356606, -2.38392833,
#         -2.24429061, -2.10465288, -1.96501516, -1.82537743, -1.6857397 ,
#         -1.54610198, -1.40646425, -1.26682653, -1.1271888 , -0.98755107,
#         -0.84791335, -0.70827562, -0.5686379 , -0.42900017, -0.28936245,
#         -0.14972472, -0.01008699,  0.12955073,  0.26918846,  0.40882618,
#          0.54846391,  0.68810164,  0.82773936,  0.96737709,  1.10701481,
#          1.24665254,  1.38629026,  1.52592799,  1.66556572,  1.80520344,
#          1.94484117,  2.08447889,  2.22411662,  2.36375435,  2.50339207,
# ...

# %%
plt.pie([8,14,15,10],explode=(0.1,0.25,0,0),autopct="1.0f%%",shadow="True")
plt.show()

# %%
plt.bar([4,6,9],[6,12,10],width=0.5)
plt.show()

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
def load_np_img(location):
    pil_img=Image.open(location)
    img=np.array(pil_img)
    return img

# %%
cb=load_np_img("pic3.png")
panda=load_np_img("panda.png")
plt.show()

# %%
pil_img=Image.open("pic3.png")

# %%
img=np.array(pil_img)

# %%
img.shape
# Out:
# (188, 484, 4)

# %%
plt.imshow(img[:,:,2],cmap="gray")
