# %%
import cv2
from matplotlib import pyplot as plt

# %%
img=cv2.imread("sample.png") # open reads in BGR manners instead of reading the RGB

# %%
plt.imshow(img)
plt.show()

# %%
newimg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)  # for covertng the BGR into RGB color

# %%
plt.imshow(newimg)
plt.show()

# %%
# Make the simple program to read and show the imgage
import cv2
# from matplotlib import pyplot as plt
img=cv2.imread("sample.png")
cv2.imshow("Valley Hill",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray=cv2.imread("sample.png")
cv2.imshow("Valley Hill",cv2.IMREAD_GRAYSCALE)
cv2.waitKey(200)
cv2.destroyAllWindows()

# %% [markdown]
# # Face detection
# - HaarCascade---->one type of classifier it is pretraint model

# %%
import cv2

cap=cv2.VideoCapture(0)
face_cascade=cv2.CascadeClassifier("Haarcascade_frontalface_alt.xml")
while True:
    ret,frame=cap.read()
    gray_frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
    if ret==False:
        continue
    faces=face_cascade.detectMultiScale(gray_frame,1.3,5)
    cv2.imshow("Video Frame",frame)
    cv2.imshow("Gray Frame",gray_frame)
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
        
    cv2.imshow("Video Frame",frame)
    
    # wait for user input -q, then you will stop the loop
    key_pressed=cv2.waitKey(1) & 0xFF
    if key_ressed==ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-37-118df03ce2cb> in <module>
#       9     if ret==False:
#      10         continue
# ---> 11     faces=face_cascade.detectMultiScale(gray_frame,1.3,5)
#      12     cv2.imshow("Video Frame",frame)
#      13     cv2.imshow("Gray Frame",gray_frame)
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'
